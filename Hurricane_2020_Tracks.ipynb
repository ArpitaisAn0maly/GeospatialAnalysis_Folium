# %%
import numpy as np 
import pandas as pd 
import os
import folium
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
storms = pd.read_csv('/dbfs/mnt/AFcovid19/AFClimate/hurricanes2020.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
storms.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[267]: Index([&#39;Given Name&#39;, &#39;Dates&#39;, &#39;Category&#39;, &#39;Mx sustained winds(Mx gusts)&#39;,
#        &#39;Lat 1&#39;, &#39;long 1&#39;, &#39; date 1&#39;, &#39;Lat 2&#39;, &#39;long 2&#39;, &#39;date 2&#39;, &#39;Lat 3&#39;,
#        &#39;long 3&#39;, &#39;date 3&#39;, &#39;Lat 4&#39;, &#39;long 4&#39;, &#39;date 4&#39;, &#39;Lat 5&#39;, &#39;long 5&#39;,
#        &#39;date 5&#39;, &#39;Lat 6&#39;, &#39;long 6&#39;, &#39;date 6&#39;, &#39;Lat 7&#39;, &#39;long 7&#39;, &#39;date 7&#39;,
# ...

# %%
#column name improvement
storms = storms.rename(columns={' date 1': 'First date'})
storms
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[268]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Given Name</th>
#       <th>Dates</th>
#       <th>Category</th>
#       <th>Mx sustained winds(Mx gusts)</th>
#       <th>Lat 1</th>
#       <th>long 1</th>
#       <th>First date</th>
#       <th>Lat 2</th>
#       <th>long 2</th>
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import folium
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Atlantic = folium.Map(location=[18.46633000, -66.10572000],
#                    zoom_start = 3)
# folium.TileLayer('Stamen Terrain').add_to(Atlantic)
# folium.TileLayer('Stamen Toner').add_to(Atlantic)
# folium.TileLayer('Stamen Water Color').add_to(Atlantic)
# folium.TileLayer('cartodbpositron').add_to(Atlantic)
# folium.TileLayer('cartodbdark_matter').add_to(Atlantic)
# folium.LayerControl().add_to(Atlantic)
# Atlantic
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# #for all systems on their first day
# for index, row in storms.iterrows():  
#     if row['Given Name']!=0: #to avoid an error      
#         folium.Marker([row['Lat 1'], row['long 1']], popup=row['Given Name'],tooltip=row["Category"]).add_to(Atlantic)
# Atlantic
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Atlantic2020 = folium.Map(
#     location=[18.46633000, -66.10572000],   
#     zoom_start=4,tiles='Stamen Terrain')
# Atlantic2020
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Arthur = storms[(storms['Given Name'] == 'Arthur')]

# Dropping columns with NaN values 
Arthur = Arthur.dropna(axis=1) 
  
Arthur
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[273]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Given Name</th>
#       <th>Dates</th>
#       <th>Category</th>
#       <th>Mx sustained winds(Mx gusts)</th>
#       <th>Lat 1</th>
#       <th>long 1</th>
#       <th>First date</th>
#       <th>Lat 2</th>
#       <th>long 2</th>
# ...

# %%
# # drop columns
# Arthur = A.drop(['Given Name','Dates','Mx sustained winds(Mx gusts)'], axis=1)
# Arthur
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
day1=Arthur[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','First date','Lat 1', 'long 1']]
day2=Arthur[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 2', 'Lat 2', 'long 2']]
day3=Arthur[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 3', 'Lat 3', 'long 3']]
day4=Arthur[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 4', 'Lat 4', 'long 4']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# day1=day1.drop(['First date'], axis=1)
# day2=day2.drop(['date 2'], axis=1)
# day3=day3.drop(['date 3'], axis=1)
# day4=day4.drop(['date 4'], axis=1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#rename columns
day1 = day1.rename(columns={'First date': 'date', 'Lat 1': 'lat', 'long 1': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day2 = day2.rename(columns={'date 2': 'date', 'Lat 2': 'lat', 'long 2': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day3 = day3.rename(columns={'date 3': 'date', 'Lat 3': 'lat', 'long 3': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day4 = day4.rename(columns={'date 4': 'date', 'Lat 4': 'lat', 'long 4': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# append days 
ArthurTrack=day1.append([day2, day3, day4]) 
ArthurTrack
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[278]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Category</th>
#       <th>Mx winds</th>
#       <th>Dates</th>
#       <th>date</th>
#       <th>lat</th>
#       <th>lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Arthur</td>
# ...

# %%
# Atlantic2020 = folium.Map(
#     location=[18.46633000, -66.10572000],   
#     zoom_start=3,tiles='Stamen Terrain')
# Atlantic2020
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
f1=folium.FeatureGroup(name='Arthur'.format(txt='red',col='red'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ArthurTrack
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[281]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Category</th>
#       <th>Mx winds</th>
#       <th>Dates</th>
#       <th>date</th>
#       <th>lat</th>
#       <th>lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Arthur</td>
# ...

# %%
# #adding trajectory 
# #Arthur 4-day track
# for index, row in ArthurTrack.iterrows():
#          popup=folium.Popup('Name : '+'Arthur'+'\n'+'Date : '+str(row['date']),max_width=800)
# #          folium.CircleMarker([row['lat'], row['lon']],
# #                             radius = 3,color='red',
# #                             popup=popup).add_to(f1) 
#          folium.map.Marker([row['lat'], row['lon']],
#                             icon=folium.Icon(color='red',icon="spinner", prefix='fa'),
#                             popup=popup).add_to(f1)  

# points = []
# for index, row in ArthurTrack.iterrows():    
#         points.append((row['lat'], row['lon']))

# folium.PolyLine(points, 
#                 color='red',popup=popup).add_to(f1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# folium.LayerControl().add_to(Atlantic2020)
# Atlantic2020
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#adding trajectory 
#Arthur 4-day track
for index, row in ArthurTrack.iterrows():
    popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
    folium.CircleMarker([row['lat'], row['lon']],
                            radius=6, color='black',fill_color='dark purple',
                            popup=popup).add_to(f1)  

points = []
for idx, point in ArthurTrack.iterrows():    
        points.append((point['lat'], point['lon']))
    
popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
folium.PolyLine(points, 
                color='red',popup=popup).add_to(f1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[284]: &lt;folium.vector_layers.PolyLine at 0x7f0737ff7af0&gt;</div>

# %%
# f1.add_to(Atlantic2020)
# folium.LayerControl().add_to(Atlantic2020)
# Atlantic2020
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Cristobal = storms[(storms['Given Name'] == 'Cristobal')]

# Dropping columns with NaN values 
Cristobal = Cristobal.dropna(axis=1) 

# # drop columns
# Cristobal = C.drop(['Given Name','Dates', 'Category','Mx sustained winds(Mx gusts)'], axis=1)
Cristobal
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[286]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Given Name</th>
#       <th>Dates</th>
#       <th>Category</th>
#       <th>Mx sustained winds(Mx gusts)</th>
#       <th>Lat 1</th>
#       <th>long 1</th>
#       <th>First date</th>
#       <th>Lat 2</th>
#       <th>long 2</th>
# ...

# %%
#Cristobal 10 day lifespan

day1=Cristobal[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','First date','Lat 1', 'long 1']]
day2=Cristobal[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 2', 'Lat 2', 'long 2']]
day3=Cristobal[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 3', 'Lat 3', 'long 3']]
day4=Cristobal[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 4', 'Lat 4', 'long 4']]
day5=Cristobal[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 5', 'Lat 5', 'long 5']]
day6=Cristobal[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 6', 'Lat 6', 'long 6']]
day7=Cristobal[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 7', 'Lat 7', 'long 7']]
day8=Cristobal[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 8', 'Lat 8', 'long 8']]
day9=Cristobal[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 9', 'Lat 9', 'long 9']]
day10=Cristobal[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 10', 'Lat 10', 'long 10']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
day1['Day 1'] = pd.to_datetime(day1['First date'])
day2['Day 2'] = pd.to_datetime(day2['date 2'])
day3['Day 3'] = pd.to_datetime(day3['date 3'])
day4['Day 4'] = pd.to_datetime(day4['date 4'])
day5['Day 5'] = pd.to_datetime(day5['date 5'])
day6['Day 6'] = pd.to_datetime(day6['date 6'])
day7['Day 7'] = pd.to_datetime(day7['date 7'])
day8['Day 8'] = pd.to_datetime(day8['date 8'])
day9['Day 9'] = pd.to_datetime(day9['date 9'])
day10['Day 10'] = pd.to_datetime(day10['date 10'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-1630276480961417&gt;:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day1[&#39;Day 1&#39;] = pd.to_datetime(day1[&#39;First date&#39;])
# &lt;command-1630276480961417&gt;:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
day1=day1.drop(['First date'], axis=1)
day2=day2.drop(['date 2'], axis=1)
day3=day3.drop(['date 3'], axis=1)
day4=day4.drop(['date 4'], axis=1)
day5=day5.drop(['date 5'], axis=1)
day6=day6.drop(['date 6'], axis=1)
day7=day7.drop(['date 7'], axis=1)
day8=day8.drop(['date 8'], axis=1)
day9=day9.drop(['date 9'], axis=1)
day10=day10.drop(['date 10'], axis=1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
day1 = day1.rename(columns={'Day 1': 'date', 'Lat 1': 'lat', 'long 1': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day2 = day2.rename(columns={'Day 2': 'date', 'Lat 2': 'lat', 'long 2': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day3 = day3.rename(columns={'Day 3': 'date', 'Lat 3': 'lat', 'long 3': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day4 = day4.rename(columns={'Day 4': 'date', 'Lat 4': 'lat', 'long 4': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day5 = day5.rename(columns={'Day 5': 'date', 'Lat 5': 'lat', 'long 5': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day6 = day6.rename(columns={'Day 6': 'date', 'Lat 6': 'lat', 'long 6': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day7 = day7.rename(columns={'Day 7': 'date', 'Lat 7': 'lat', 'long 7': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day8 = day8.rename(columns={'Day 8': 'date', 'Lat 8': 'lat', 'long 8': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day9 = day9.rename(columns={'Day 9': 'date', 'Lat 9': 'lat', 'long 9': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day10 = day10.rename(columns={'Day 10': 'date', 'Lat 10': 'lat', 'long 10': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
CristobalTrack=day1.append([day2, day3, day4, day5, day6, day7, day8, day9, day10]) 
CristobalTrack
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[291]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Category</th>
#       <th>Mx winds</th>
#       <th>Dates</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>Cristobal</td>
# ...

# %%
f2=folium.FeatureGroup(name='Cristobal'.format(txt='green',col='green'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Cristobal 10-day track
for index, row in CristobalTrack.iterrows():
          popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
          folium.CircleMarker([row['lat'], row['lon']],
                            radius=6, color='black',fill_color='green',
                            popup=popup).add_to(f2)         
#adding trajectory 

pointsC = []
for idx, point in CristobalTrack.iterrows():  
      
        pointsC.append((point['lat'], point['lon']))
popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
folium.PolyLine(pointsC,popup=popup, 
                color='green').add_to(f2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[293]: &lt;folium.vector_layers.PolyLine at 0x7f0737fbe9a0&gt;</div>

# %%
# f2.add_to(Atlantic2020)
# f1.add_to(Atlantic2020)
# folium.LayerControl().add_to(Atlantic2020)
# Atlantic2020
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Hanna
Hanna = storms[(storms['Given Name'] == 'Hanna')]

# Dropping columns with NaN values 
Hanna = Hanna.dropna(axis=1) 

# # drop columns
# Hanna = H.drop(['Given Name','Dates', 'Category','Mx sustained winds(Mx gusts)'], axis=1)
Hanna
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[295]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Given Name</th>
#       <th>Dates</th>
#       <th>Category</th>
#       <th>Mx sustained winds(Mx gusts)</th>
#       <th>Lat 1</th>
#       <th>long 1</th>
#       <th>First date</th>
#       <th>Lat 2</th>
#       <th>long 2</th>
# ...

# %%
#breaking into small dataframes (per day)
day1=Hanna[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','First date','Lat 1', 'long 1']]
day2=Hanna[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 2', 'Lat 2', 'long 2']]
day3=Hanna[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 3', 'Lat 3', 'long 3']]
day4=Hanna[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 4', 'Lat 4', 'long 4']]
day5=Hanna[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 5', 'Lat 5', 'long 5']]

#transform string to datetime format
day1['Day 1'] = pd.to_datetime(day1['First date'])
day2['Day 2'] = pd.to_datetime(day2['date 2'])
day3['Day 3'] = pd.to_datetime(day3['date 3'])
day4['Day 4'] = pd.to_datetime(day4['date 4'])
day5['Day 5'] = pd.to_datetime(day5['date 5'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-1630276480961425&gt;:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day1[&#39;Day 1&#39;] = pd.to_datetime(day1[&#39;First date&#39;])
# &lt;command-1630276480961425&gt;:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#drop unnecessary columns
day1=day1.drop(['First date'], axis=1)
day2=day2.drop(['date 2'], axis=1)
day3=day3.drop(['date 3'], axis=1)
day4=day4.drop(['date 4'], axis=1)
day5=day5.drop(['date 5'], axis=1)

#rename columns
day1 = day1.rename(columns={'Day 1': 'date', 'Lat 1': 'lat', 'long 1': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day2 = day2.rename(columns={'Day 2': 'date', 'Lat 2': 'lat', 'long 2': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day3 = day3.rename(columns={'Day 3': 'date', 'Lat 3': 'lat', 'long 3': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day4 = day4.rename(columns={'Day 4': 'date', 'Lat 4': 'lat', 'long 4': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day5 = day5.rename(columns={'Day 5': 'date', 'Lat 5': 'lat', 'long 5': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# append days dataframes into one 
HannaTrack=day1.append([day2, day3, day4, day5]) 
HannaTrack
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[298]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Category</th>
#       <th>Mx winds</th>
#       <th>Dates</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7</th>
#       <td>Hanna</td>
# ...

# %%
f3=folium.FeatureGroup(name='Hanna'.format(txt='saddlebrown',col='saddlebrown'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Adding Hanna's 5-day track

for index, row in HannaTrack.iterrows():
         popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
         folium.CircleMarker([row['lat'], row['lon']],
                            radius=6, color='black',fill_color='saddlebrown',
                            popup=popup).add_to(f3)         
#adding trajectory 

pointsH = []
for idx, point in HannaTrack.iterrows():    
        pointsH.append((point['lat'], point['lon']))
popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
folium.PolyLine(pointsH, color='saddlebrown',popup=popup).add_to(f3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[300]: &lt;folium.vector_layers.PolyLine at 0x7f073800f280&gt;</div>

# %%
# f3.add_to(Atlantic2020)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Isaias

Isaias = storms[(storms['Given Name'] == 'Isaias')]

# Dropping columns with NaN values 
Isaias = Isaias.dropna(axis=1) 

# drop columns
# Isaias = i.drop(['Given Name','Dates', 'Category','Mx sustained winds(Mx gusts)'], axis=1)
Isaias
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[302]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Given Name</th>
#       <th>Dates</th>
#       <th>Category</th>
#       <th>Mx sustained winds(Mx gusts)</th>
#       <th>Lat 1</th>
#       <th>long 1</th>
#       <th>First date</th>
#       <th>Lat 2</th>
#       <th>long 2</th>
# ...

# %%
#Isaias 9-day lifespan
day1=Isaias[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','First date','Lat 1', 'long 1']]
day2=Isaias[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 2', 'Lat 2', 'long 2']]
day3=Isaias[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 3', 'Lat 3', 'long 3']]
day4=Isaias[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 4', 'Lat 4', 'long 4']]
day5=Isaias[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 5', 'Lat 5', 'long 5']]
day6=Isaias[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 6', 'Lat 6', 'long 6']]
day7=Isaias[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 7', 'Lat 7', 'long 7']]
day8=Isaias[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 8', 'Lat 8', 'long 8']]
day9=Isaias[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 9', 'Lat 9', 'long 9']]

#coverting string to datetime
day1['Day 1'] = pd.to_datetime(day1['First date'])
day2['Day 2'] = pd.to_datetime(day2['date 2'])
day3['Day 3'] = pd.to_datetime(day3['date 3'])
day4['Day 4'] = pd.to_datetime(day4['date 4'])
day5['Day 5'] = pd.to_datetime(day5['date 5'])
day6['Day 6'] = pd.to_datetime(day6['date 6'])
day7['Day 7'] = pd.to_datetime(day7['date 7'])
day8['Day 8'] = pd.to_datetime(day8['date 8'])
day9['Day 9'] = pd.to_datetime(day9['date 9'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-1630276480961432&gt;:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day1[&#39;Day 1&#39;] = pd.to_datetime(day1[&#39;First date&#39;])
# &lt;command-1630276480961432&gt;:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#drop columns
day1=day1.drop(['First date'], axis=1)
day2=day2.drop(['date 2'], axis=1)
day3=day3.drop(['date 3'], axis=1)
day4=day4.drop(['date 4'], axis=1)
day5=day5.drop(['date 5'], axis=1)
day6=day6.drop(['date 6'], axis=1)
day7=day7.drop(['date 7'], axis=1)
day8=day8.drop(['date 8'], axis=1)
day9=day9.drop(['date 9'], axis=1)

#rename columns
day1 = day1.rename(columns={'Day 1': 'date', 'Lat 1': 'lat', 'long 1': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day2 = day2.rename(columns={'Day 2': 'date', 'Lat 2': 'lat', 'long 2': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day3 = day3.rename(columns={'Day 3': 'date', 'Lat 3': 'lat', 'long 3': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day4 = day4.rename(columns={'Day 4': 'date', 'Lat 4': 'lat', 'long 4': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day5 = day5.rename(columns={'Day 5': 'date', 'Lat 5': 'lat', 'long 5': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day6 = day6.rename(columns={'Day 6': 'date', 'Lat 6': 'lat', 'long 6': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day7 = day7.rename(columns={'Day 7': 'date', 'Lat 7': 'lat', 'long 7': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day8 = day8.rename(columns={'Day 8': 'date', 'Lat 8': 'lat', 'long 8': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day9 = day9.rename(columns={'Day 9': 'date', 'Lat 9': 'lat', 'long 9': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# append days dataframes into one 
IsaiasTrack=day1.append([day2, day3, day4, day5, day6, day7, day8, day9]) 
IsaiasTrack
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[305]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Category</th>
#       <th>Mx winds</th>
#       <th>Dates</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>8</th>
#       <td>Isaias</td>
# ...

# %%
f4=folium.FeatureGroup(name='Isaias'.format(txt='gray',col='gray'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Adding Isaias's 10-day track

for index, row in IsaiasTrack.iterrows():
        popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
        folium.CircleMarker([row['lat'], row['lon']],
                            radius=6, color='black',fill_color='gray',
                            popup=popup).add_to(f4)         
#adding trajectory 

pointsI = []
for idx, point in IsaiasTrack.iterrows():    
        pointsI.append((point['lat'], point['lon']))
popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
folium.PolyLine(pointsI, color='gray',popup=popup).add_to(f4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[307]: &lt;folium.vector_layers.PolyLine at 0x7f0737fe22b0&gt;</div>

# %%
# f4.add_to(Atlantic2020)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Laura
Laura = storms[(storms['Given Name'] == 'Laura')]

# Dropping columns with NaN values 
Laura = Laura.dropna(axis=1) 

# drop columns
# Laura = l.drop(['Given Name','Dates', 'Category','Mx sustained winds(Mx gusts)'], axis=1)
Laura
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[309]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Given Name</th>
#       <th>Dates</th>
#       <th>Category</th>
#       <th>Mx sustained winds(Mx gusts)</th>
#       <th>Lat 1</th>
#       <th>long 1</th>
#       <th>First date</th>
#       <th>Lat 2</th>
#       <th>long 2</th>
# ...

# %%
#Lauras 10-day lifespan
day1=Laura[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','First date','Lat 1', 'long 1']]
day2=Laura[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 2', 'Lat 2', 'long 2']]
day3=Laura[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 3', 'Lat 3', 'long 3']]
day4=Laura[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 4', 'Lat 4', 'long 4']]
day5=Laura[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 5', 'Lat 5', 'long 5']]
day6=Laura[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 6', 'Lat 6', 'long 6']]
day7=Laura[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 7', 'Lat 7', 'long 7']]
day8=Laura[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 8', 'Lat 8', 'long 8']]
day9=Laura[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 9', 'Lat 9', 'long 9']]
day10=Laura[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 10', 'Lat 10', 'long 10']]

#coverting string to datetime
day1['Day 1'] = pd.to_datetime(day1['First date'])
day2['Day 2'] = pd.to_datetime(day2['date 2'])
day3['Day 3'] = pd.to_datetime(day3['date 3'])
day4['Day 4'] = pd.to_datetime(day4['date 4'])
day5['Day 5'] = pd.to_datetime(day5['date 5'])
day6['Day 6'] = pd.to_datetime(day6['date 6'])
day7['Day 7'] = pd.to_datetime(day7['date 7'])
day8['Day 8'] = pd.to_datetime(day8['date 8'])
day9['Day 9'] = pd.to_datetime(day9['date 9'])
day10['Day 10'] = pd.to_datetime(day10['date 10'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-1630276480961439&gt;:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day1[&#39;Day 1&#39;] = pd.to_datetime(day1[&#39;First date&#39;])
# &lt;command-1630276480961439&gt;:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#drop columns
day1=day1.drop(['First date'], axis=1)
day2=day2.drop(['date 2'], axis=1)
day3=day3.drop(['date 3'], axis=1)
day4=day4.drop(['date 4'], axis=1)
day5=day5.drop(['date 5'], axis=1)
day6=day6.drop(['date 6'], axis=1)
day7=day7.drop(['date 7'], axis=1)
day8=day8.drop(['date 8'], axis=1)
day9=day9.drop(['date 9'], axis=1)
day10=day10.drop(['date 10'], axis=1)

#rename columns
day1 = day1.rename(columns={'Day 1': 'date', 'Lat 1': 'lat', 'long 1': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day2 = day2.rename(columns={'Day 2': 'date', 'Lat 2': 'lat', 'long 2': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day3 = day3.rename(columns={'Day 3': 'date', 'Lat 3': 'lat', 'long 3': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day4 = day4.rename(columns={'Day 4': 'date', 'Lat 4': 'lat', 'long 4': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day5 = day5.rename(columns={'Day 5': 'date', 'Lat 5': 'lat', 'long 5': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day6 = day6.rename(columns={'Day 6': 'date', 'Lat 6': 'lat', 'long 6': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day7 = day7.rename(columns={'Day 7': 'date', 'Lat 7': 'lat', 'long 7': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day8 = day8.rename(columns={'Day 8': 'date', 'Lat 8': 'lat', 'long 8': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day9 = day9.rename(columns={'Day 9': 'date', 'Lat 9': 'lat', 'long 9': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day10 = day10.rename(columns={'Day 10': 'date', 'Lat 10': 'lat', 'long 10': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# append days dataframes into one 
LauraTrack=day1.append([day2, day3, day4, day5, day6, day7, day8, day9, day10]) 
LauraTrack
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[312]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Category</th>
#       <th>Mx winds</th>
#       <th>Dates</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>12</th>
#       <td>Laura</td>
# ...

# %%
f5=folium.FeatureGroup(name='Laura'.format(txt='mediumspringgreen',col='mediumspringgreen'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Adding Laura 10-day track

for index, row in LauraTrack.iterrows():
      popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
      folium.CircleMarker([row['lat'], row['lon']],
                            radius=6, color='black',fill_color='mediumspringgreen',
                            popup=popup).add_to(f5) 
    
            
#adding trajectory 

pointsL = []
for idx, point in LauraTrack.iterrows():    
        pointsL.append((point['lat'], point['lon']))
popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
folium.PolyLine(pointsL, color='mediumspringgreen',popup=popup).add_to(f5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[314]: &lt;folium.vector_layers.PolyLine at 0x7f0737fedac0&gt;</div>

# %%
# f5.add_to(Atlantic2020)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Marco
Marco = storms[(storms['Given Name'] == 'Marco')]

# Dropping columns with NaN values 
Marco = Marco.dropna(axis=1) 

# drop columns
# Marco = m.drop(['Given Name','Dates', 'Category','Mx sustained winds(Mx gusts)'], axis=1)
Marco
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[316]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Given Name</th>
#       <th>Dates</th>
#       <th>Category</th>
#       <th>Mx sustained winds(Mx gusts)</th>
#       <th>Lat 1</th>
#       <th>long 1</th>
#       <th>First date</th>
#       <th>Lat 2</th>
#       <th>long 2</th>
# ...

# %%
day1=Marco[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','First date','Lat 1', 'long 1']]
day2=Marco[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 2', 'Lat 2', 'long 2']]
day3=Marco[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 3', 'Lat 3', 'long 3']]
day4=Marco[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 4', 'Lat 4', 'long 4']]
day5=Marco[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 5', 'Lat 5', 'long 5']]
day6=Marco[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 6', 'Lat 6', 'long 6']]

#transform string to datetime format
day1['Day 1'] = pd.to_datetime(day1['First date'])
day2['Day 2'] = pd.to_datetime(day2['date 2'])
day3['Day 3'] = pd.to_datetime(day3['date 3'])
day4['Day 4'] = pd.to_datetime(day4['date 4'])
day5['Day 5'] = pd.to_datetime(day5['date 5'])
day6['Day 6'] = pd.to_datetime(day6['date 6'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-1630276480961446&gt;:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day1[&#39;Day 1&#39;] = pd.to_datetime(day1[&#39;First date&#39;])
# &lt;command-1630276480961446&gt;:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#drop columns
day1=day1.drop(['First date'], axis=1)
day2=day2.drop(['date 2'], axis=1)
day3=day3.drop(['date 3'], axis=1)
day4=day4.drop(['date 4'], axis=1)
day5=day5.drop(['date 5'], axis=1)
day6=day6.drop(['date 6'], axis=1)

#rename columns
day1 = day1.rename(columns={'Day 1': 'date', 'Lat 1': 'lat', 'long 1': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day2 = day2.rename(columns={'Day 2': 'date', 'Lat 2': 'lat', 'long 2': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day3 = day3.rename(columns={'Day 3': 'date', 'Lat 3': 'lat', 'long 3': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day4 = day4.rename(columns={'Day 4': 'date', 'Lat 4': 'lat', 'long 4': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day5 = day5.rename(columns={'Day 5': 'date', 'Lat 5': 'lat', 'long 5': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day6 = day6.rename(columns={'Day 6': 'date', 'Lat 6': 'lat', 'long 6': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# append days dataframes into one 
MarcoTrack=day1.append([day2, day3, day4, day5, day6]) 
MarcoTrack
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[319]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Category</th>
#       <th>Mx winds</th>
#       <th>Dates</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>13</th>
#       <td>Marco</td>
# ...

# %%
f6=folium.FeatureGroup(name='Marco'.format(txt='indigo',col='indigo'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Adding Marco 6-day track

for index, row in MarcoTrack.iterrows():
         popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
         folium.CircleMarker([row['lat'], row['lon']],
                            radius=6, color='black',fill_color='indigo',
                            popup=popup).add_to(f5).add_to(f6)         
#adding trajectory 

pointsM = []
for idx, point in MarcoTrack.iterrows():    
        pointsM.append((point['lat'], point['lon']))
popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
folium.PolyLine(pointsM, color='indigo',popup=popup).add_to(f6)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[321]: &lt;folium.vector_layers.PolyLine at 0x7f0737f75e80&gt;</div>

# %%
# Atlantic2021 = folium.Map(
#     location=[18.46633000, -66.10572000],   
#     zoom_start=4,tiles='Stamen Terrain')
# Atlantic2021
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Teddy
Teddy = storms[(storms['Given Name'] == 'Teddy')]

# Dropping columns with NaN values 
Teddy = Teddy.dropna(axis=1) 

# drop columns
# Teddy = ted.drop(['Given Name','Dates', 'Category','Mx sustained winds(Mx gusts)'], axis=1)
Teddy
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[323]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Given Name</th>
#       <th>Dates</th>
#       <th>Category</th>
#       <th>Mx sustained winds(Mx gusts)</th>
#       <th>Lat 1</th>
#       <th>long 1</th>
#       <th>First date</th>
#       <th>Lat 2</th>
#       <th>long 2</th>
# ...

# %%
#13-day lifespan
day1=Teddy[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','First date','Lat 1', 'long 1']]
day2=Teddy[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 2', 'Lat 2', 'long 2']]
day3=Teddy[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 3', 'Lat 3', 'long 3']]
day4=Teddy[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 4', 'Lat 4', 'long 4']]
day5=Teddy[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 5', 'Lat 5', 'long 5']]
day6=Teddy[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 6', 'Lat 6', 'long 6']]
day7=Teddy[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 7', 'Lat 7', 'long 7']]
day8=Teddy[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 8', 'Lat 8', 'long 8']]
day9=Teddy[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 9', 'Lat 9', 'long 9']]
day10=Teddy[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 10', 'Lat 10', 'long 10']]
day11=Teddy[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 11', 'Lat 11', 'long 11']]
day12=Teddy[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 12', 'Lat 12', 'long 12']]
day13=Teddy[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 13', 'Lat 13', 'long 13']]

#coverting string to datetime
day1['Day 1'] = pd.to_datetime(day1['First date'])
day2['Day 2'] = pd.to_datetime(day2['date 2'])
day3['Day 3'] = pd.to_datetime(day3['date 3'])
day4['Day 4'] = pd.to_datetime(day4['date 4'])
day5['Day 5'] = pd.to_datetime(day5['date 5'])
day6['Day 6'] = pd.to_datetime(day6['date 6'])
day7['Day 7'] = pd.to_datetime(day7['date 7'])
day8['Day 8'] = pd.to_datetime(day8['date 8'])
day9['Day 9'] = pd.to_datetime(day9['date 9'])
day10['Day 10'] = pd.to_datetime(day10['date 10'])
day11['Day 11'] = pd.to_datetime(day11['date 11'])
day12['Day 12'] = pd.to_datetime(day12['date 12'])
day13['Day 13'] = pd.to_datetime(day13['date 13'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-1630276480961453&gt;:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day1[&#39;Day 1&#39;] = pd.to_datetime(day1[&#39;First date&#39;])
# &lt;command-1630276480961453&gt;:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#drop columns
day1=day1.drop(['First date'], axis=1)
day2=day2.drop(['date 2'], axis=1)
day3=day3.drop(['date 3'], axis=1)
day4=day4.drop(['date 4'], axis=1)
day5=day5.drop(['date 5'], axis=1)
day6=day6.drop(['date 6'], axis=1)
day7=day7.drop(['date 7'], axis=1)
day8=day8.drop(['date 8'], axis=1)
day9=day9.drop(['date 9'], axis=1)
day10=day10.drop(['date 10'], axis=1)
day11=day11.drop(['date 11'], axis=1)
day12=day12.drop(['date 12'], axis=1)
day13=day13.drop(['date 13'], axis=1)

#rename columns
day1 = day1.rename(columns={'Day 1': 'date', 'Lat 1': 'lat', 'long 1': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day2 = day2.rename(columns={'Day 2': 'date', 'Lat 2': 'lat', 'long 2': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day3 = day3.rename(columns={'Day 3': 'date', 'Lat 3': 'lat', 'long 3': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day4 = day4.rename(columns={'Day 4': 'date', 'Lat 4': 'lat', 'long 4': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day5 = day5.rename(columns={'Day 5': 'date', 'Lat 5': 'lat', 'long 5': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day6 = day6.rename(columns={'Day 6': 'date', 'Lat 6': 'lat', 'long 6': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day7 = day7.rename(columns={'Day 7': 'date', 'Lat 7': 'lat', 'long 7': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day8 = day8.rename(columns={'Day 8': 'date', 'Lat 8': 'lat', 'long 8': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day9 = day9.rename(columns={'Day 9': 'date', 'Lat 9': 'lat', 'long 9': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day10 = day10.rename(columns={'Day 10': 'date', 'Lat 10': 'lat', 'long 10': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day11 = day11.rename(columns={'Day 11': 'date', 'Lat 11': 'lat', 'long 11': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day12 = day12.rename(columns={'Day 12': 'date', 'Lat 12': 'lat', 'long 12': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day13 = day13.rename(columns={'Day 13': 'date', 'Lat 13': 'lat', 'long 13': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# append days dataframes into one 
TeddyTrack=day1.append([day2, day3, day4, day5, day6, day7, day8, 
                       day9, day10, day11, day12, day13]) 
TeddyTrack
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[326]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Category</th>
#       <th>Mx winds</th>
#       <th>Dates</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>19</th>
#       <td>Teddy</td>
# ...

# %%
f7=folium.FeatureGroup(name='Teddy'.format(txt='darkslategray',col='darkslategray'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Adding Teddy's 13-day track

for index, row in TeddyTrack.iterrows():
       popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
       folium.CircleMarker([row['lat'], row['lon']],
                            radius=6, color='black',fill_color='darkslategray',
                            popup=popup).add_to(f7)         
#adding trajectory 

pointsTed = []
for idx, point in TeddyTrack.iterrows():    
        pointsTed.append((point['lat'], point['lon']))
popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
folium.PolyLine(pointsTed, color='darkslategray', popup=popup).add_to(f7)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[328]: &lt;folium.vector_layers.PolyLine at 0x7f0737f909d0&gt;</div>

# %%
# f7.add_to(Atlantic2020)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Iota
Iota = storms[(storms['Given Name'] == 'Iota')]

# Dropping columns with NaN values 
Iota = Iota.dropna(axis=1) 

# drop columns
# Iota = io.drop(['Given Name','Dates', 'Category','Mx sustained winds(Mx gusts)'], axis=1)
Iota
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[330]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Given Name</th>
#       <th>Dates</th>
#       <th>Category</th>
#       <th>Mx sustained winds(Mx gusts)</th>
#       <th>Lat 1</th>
#       <th>long 1</th>
#       <th>First date</th>
#       <th>Lat 2</th>
#       <th>long 2</th>
# ...

# %%
day1=Iota[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','First date','Lat 1', 'long 1']]
day2=Iota[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 2', 'Lat 2', 'long 2']]
day3=Iota[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 3', 'Lat 3', 'long 3']]
day4=Iota[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 4', 'Lat 4', 'long 4']]
day5=Iota[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 5', 'Lat 5', 'long 5']]
day6=Iota[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 6', 'Lat 6', 'long 6']]


#coverting string to datetime
day1['Day 1'] = pd.to_datetime(day1['First date'])
day2['Day 2'] = pd.to_datetime(day2['date 2'])
day3['Day 3'] = pd.to_datetime(day3['date 3'])
day4['Day 4'] = pd.to_datetime(day4['date 4'])
day5['Day 5'] = pd.to_datetime(day5['date 5'])
day6['Day 6'] = pd.to_datetime(day6['date 6'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-1630276480961460&gt;:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day1[&#39;Day 1&#39;] = pd.to_datetime(day1[&#39;First date&#39;])
# &lt;command-1630276480961460&gt;:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
day1=day1.drop(['First date'], axis=1)
day2=day2.drop(['date 2'], axis=1)
day3=day3.drop(['date 3'], axis=1)
day4=day4.drop(['date 4'], axis=1)
day5=day5.drop(['date 5'], axis=1)
day6=day6.drop(['date 6'], axis=1)


#rename columns
day1 = day1.rename(columns={'Day 1': 'date', 'Lat 1': 'lat', 'long 1': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day2 = day2.rename(columns={'Day 2': 'date', 'Lat 2': 'lat', 'long 2': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day3 = day3.rename(columns={'Day 3': 'date', 'Lat 3': 'lat', 'long 3': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day4 = day4.rename(columns={'Day 4': 'date', 'Lat 4': 'lat', 'long 4': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day5 = day5.rename(columns={'Day 5': 'date', 'Lat 5': 'lat', 'long 5': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day6 = day6.rename(columns={'Day 6': 'date', 'Lat 6': 'lat', 'long 6': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
IotaTrack=day1.append([day2, day3, day4, day5, day6]) 
IotaTrack
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[333]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Category</th>
#       <th>Mx winds</th>
#       <th>Dates</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>30</th>
#       <td>Iota</td>
# ...

# %%
f8=folium.FeatureGroup(name='Iota'.format(txt='silver',col='silver'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
for index, row in IotaTrack.iterrows():
       popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
       folium.CircleMarker([row['lat'], row['lon']],
                            radius=6, color='black',fill_color='silver',
                            popup=popup).add_to(f8)         
#adding trajectory 

pointsIo = []
for idx, point in IotaTrack.iterrows():    
        pointsIo.append((point['lat'], point['lon']))
popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
folium.PolyLine(pointsIo, color='silver',popup=popup).add_to(f8)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[335]: &lt;folium.vector_layers.PolyLine at 0x7f0737f75160&gt;</div>

# %%
# f8.add_to(Atlantic2020)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Bertha = storms[(storms['Given Name'] == 'Bertha')]

# Dropping columns with NaN values 
Bertha = Bertha.dropna(axis=1) 
  
Bertha
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[337]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Given Name</th>
#       <th>Dates</th>
#       <th>Category</th>
#       <th>Mx sustained winds(Mx gusts)</th>
#       <th>Lat 1</th>
#       <th>long 1</th>
#       <th>First date</th>
#       <th>Lat 2</th>
#       <th>long 2</th>
# ...

# %%
# # drop columns
# Bertha = B.drop(['Given Name','Dates', 'Category','Mx sustained winds(Mx gusts)'], axis=1)
# Bertha
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
day1=Bertha[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','First date','Lat 1', 'long 1']]
day2=Bertha[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 2', 'Lat 2', 'long 2']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
day1['Day 1'] = pd.to_datetime(day1['First date'])
day2['Day 2'] = pd.to_datetime(day2['date 2'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-1630276480961469&gt;:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day1[&#39;Day 1&#39;] = pd.to_datetime(day1[&#39;First date&#39;])
# &lt;command-1630276480961469&gt;:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
day1=day1.drop(['First date'], axis=1)
day2=day2.drop(['date 2'], axis=1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
day1 = day1.rename(columns={'Day 1': 'date', 'Lat 1': 'lat', 'long 1': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day2 = day2.rename(columns={'Day 2': 'date', 'Lat 2': 'lat', 'long 2': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# append days 
BerthaTrack=day1.append([day2]) 
BerthaTrack
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[343]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Category</th>
#       <th>Mx winds</th>
#       <th>Dates</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Bertha</td>
# ...

# %%
f9=folium.FeatureGroup(name='Bertha'.format(txt='blue',col='blue'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Bertha 2-day track
for index, row in BerthaTrack.iterrows():
       popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
       folium.CircleMarker([row['lat'], row['lon']],
                            radius=6, color='black',fill_color='blue',
                            popup=popup).add_to(f9)         
#adding trajectory 

pointsB = []
for idx, point in BerthaTrack.iterrows():    
        pointsB.append((point['lat'], point['lon']))
    
popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
folium.PolyLine(pointsB, 
                color='blue',popup=popup).add_to(f9)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[345]: &lt;folium.vector_layers.PolyLine at 0x7f0738061c10&gt;</div>

# %%
# f9.add_to(Atlantic2020)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Dolly = storms[(storms['Given Name'] == 'Dolly')]

# Dropping columns with NaN values 
Dolly = Dolly.dropna(axis=1) 

# drop columns
# Dolly = D.drop(['Given Name','Dates', 'Category','Mx sustained winds(Mx gusts)'], axis=1)
Dolly
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[347]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Given Name</th>
#       <th>Dates</th>
#       <th>Category</th>
#       <th>Mx sustained winds(Mx gusts)</th>
#       <th>Lat 1</th>
#       <th>long 1</th>
#       <th>First date</th>
#       <th>Lat 2</th>
#       <th>long 2</th>
# ...

# %%
day1=Dolly[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','First date','Lat 1', 'long 1']]
day2=Dolly[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 2', 'Lat 2', 'long 2']]
day3=Dolly[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 3', 'Lat 3', 'long 3']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
day1['Day 1'] = pd.to_datetime(day1['First date'])
day2['Day 2'] = pd.to_datetime(day2['date 2'])
day3['Day 3'] = pd.to_datetime(day3['date 3'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-1630276480961478&gt;:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day1[&#39;Day 1&#39;] = pd.to_datetime(day1[&#39;First date&#39;])
# &lt;command-1630276480961478&gt;:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
day1=day1.drop(['First date'], axis=1)
day2=day2.drop(['date 2'], axis=1)
day3=day3.drop(['date 3'], axis=1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#rename columns
day1 = day1.rename(columns={'Day 1': 'date', 'Lat 1': 'lat', 'long 1': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day2 = day2.rename(columns={'Day 2': 'date', 'Lat 2': 'lat', 'long 2': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day3 = day3.rename(columns={'Day 3': 'date', 'Lat 3': 'lat', 'long 3': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# append days 
DollyTrack=day1.append([day2, day3]) 
DollyTrack
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[352]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Category</th>
#       <th>Mx winds</th>
#       <th>Dates</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>Dolly</td>
# ...

# %%
f10=folium.FeatureGroup(name='Dolly'.format(txt='orange',col='orange'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Dolly 3-day track
for index, row in DollyTrack.iterrows():
       popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
       folium.CircleMarker([row['lat'], row['lon']],
                            radius=6, color='black',fill_color='orange',
                            popup=popup).add_to(f10)         
#adding trajectory 

pointsd = []
for idx, point in DollyTrack.iterrows():    
        pointsd.append((point['lat'], point['lon']))
popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
folium.PolyLine(pointsd, 
                color='orange',popup=popup).add_to(f10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[354]: &lt;folium.vector_layers.PolyLine at 0x7f0737f52ca0&gt;</div>

# %%
# f10.add_to(Atlantic2020)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Edouard
Edouard = storms[(storms['Given Name'] == 'Edouard')]

# Dropping columns with NaN values 
Edouard = Edouard.dropna(axis=1) 

# drop columns
# Edouard = E.drop(['Given Name','Dates', 'Category','Mx sustained winds(Mx gusts)'], axis=1)
Edouard
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[356]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Given Name</th>
#       <th>Dates</th>
#       <th>Category</th>
#       <th>Mx sustained winds(Mx gusts)</th>
#       <th>Lat 1</th>
#       <th>long 1</th>
#       <th>First date</th>
#       <th>Lat 2</th>
#       <th>long 2</th>
# ...

# %%
#breaking Edouard into small dataframes (per day)
day1=Edouard[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','First date','Lat 1', 'long 1']]
day2=Edouard[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 2', 'Lat 2', 'long 2']]
day3=Edouard[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 3', 'Lat 3', 'long 3']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#transform string to datetime formay
day1['Day 1'] = pd.to_datetime(day1['First date'])
day2['Day 2'] = pd.to_datetime(day2['date 2'])
day3['Day 3'] = pd.to_datetime(day3['date 3'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-1630276480961487&gt;:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day1[&#39;Day 1&#39;] = pd.to_datetime(day1[&#39;First date&#39;])
# &lt;command-1630276480961487&gt;:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#drop unnecessary columns
day1=day1.drop(['First date'], axis=1)
day2=day2.drop(['date 2'], axis=1)
day3=day3.drop(['date 3'], axis=1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#rename columns
day1 = day1.rename(columns={'Day 1': 'date', 'Lat 1': 'lat', 'long 1': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day2 = day2.rename(columns={'Day 2': 'date', 'Lat 2': 'lat', 'long 2': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day3 = day3.rename(columns={'Day 3': 'date', 'Lat 3': 'lat', 'long 3': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# append days dataframes into one 
EdouardTrack=day1.append([day2, day3]) 
EdouardTrack
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[361]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Category</th>
#       <th>Mx winds</th>
#       <th>Dates</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4</th>
#       <td>Edouard</td>
# ...

# %%
f11=folium.FeatureGroup(name='Edouard'.format(txt='gold',col='gold'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Edouard 3-day track
for index, row in EdouardTrack.iterrows():
  
       popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
       folium.CircleMarker([row['lat'], row['lon']],
                            radius=6, color='black',fill_color='gold',
                            popup=popup).add_to(f11)  
#adding trajectory 

pointsE = []
for idx, point in EdouardTrack.iterrows():    
        pointsE.append((point['lat'], point['lon']))
    
    
popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
folium.PolyLine(pointsE, 
                color='gold',popup=popup).add_to(f11)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[363]: &lt;folium.vector_layers.PolyLine at 0x7f0737f368e0&gt;</div>

# %%
# f11.add_to(Atlantic2020)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Fay

Fay = storms[(storms['Given Name'] == 'Fay')]

# Dropping columns with NaN values 
Fay = Fay.dropna(axis=1) 

# drop columns
# Fay = F.drop(['Given Name','Dates', 'Category','Mx sustained winds(Mx gusts)'], axis=1)
Fay
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[365]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Given Name</th>
#       <th>Dates</th>
#       <th>Category</th>
#       <th>Mx sustained winds(Mx gusts)</th>
#       <th>Lat 1</th>
#       <th>long 1</th>
#       <th>First date</th>
#       <th>Lat 2</th>
#       <th>long 2</th>
# ...

# %%
day1=Fay[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','First date','Lat 1', 'long 1']]
day2=Fay[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 2', 'Lat 2', 'long 2']]
day3=Fay[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 3', 'Lat 3', 'long 3']]

#transform string to datetime formay
day1['Day 1'] = pd.to_datetime(day1['First date'])
day2['Day 2'] = pd.to_datetime(day2['date 2'])
day3['Day 3'] = pd.to_datetime(day3['date 3'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-1630276480961495&gt;:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day1[&#39;Day 1&#39;] = pd.to_datetime(day1[&#39;First date&#39;])
# &lt;command-1630276480961495&gt;:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#drop unnecessary columns
day1=day1.drop(['First date'], axis=1)
day2=day2.drop(['date 2'], axis=1)
day3=day3.drop(['date 3'], axis=1)

#rename columns
day1 = day1.rename(columns={'Day 1': 'date', 'Lat 1': 'lat', 'long 1': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day2 = day2.rename(columns={'Day 2': 'date', 'Lat 2': 'lat', 'long 2': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day3 = day3.rename(columns={'Day 3': 'date', 'Lat 3': 'lat', 'long 3': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# append days dataframes into one 
FayTrack=day1.append([day2, day3]) 
FayTrack
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[368]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Category</th>
#       <th>Mx winds</th>
#       <th>Dates</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
#       <td>Fay</td>
# ...

# %%
f12=folium.FeatureGroup(name='Fay'.format(txt='purple',col='purple'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Fay 3-day track
for index, row in FayTrack.iterrows():
         popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
         folium.CircleMarker([row['lat'], row['lon']],
                            radius=6, color='black',fill_color='purple',
                            popup=popup).add_to(f12)         
#adding trajectory 

pointsF = []
for idx, point in FayTrack.iterrows():    
        pointsF.append((point['lat'], point['lon']))
    
popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
folium.PolyLine(pointsF, 
                color='purple', popup=popup).add_to(f12)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[370]: &lt;folium.vector_layers.PolyLine at 0x7f0737f61850&gt;</div>

# %%
# f12.add_to(Atlantic2020)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Gonzalo
Gonzalo = storms[(storms['Given Name'] == 'Gonzalo')]

# Dropping columns with NaN values 
Gonzalo = Gonzalo.dropna(axis=1) 

# drop columns
# Gonzalo = G.drop(['Given Name','Dates', 'Category','Mx sustained winds(Mx gusts)'], axis=1)
Gonzalo
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[372]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Given Name</th>
#       <th>Dates</th>
#       <th>Category</th>
#       <th>Mx sustained winds(Mx gusts)</th>
#       <th>Lat 1</th>
#       <th>long 1</th>
#       <th>First date</th>
#       <th>Lat 2</th>
#       <th>long 2</th>
# ...

# %%
#breaking into small dataframes (per day)
day1=Gonzalo[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','First date','Lat 1', 'long 1']]
day2=Gonzalo[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 2', 'Lat 2', 'long 2']]
day3=Gonzalo[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 3', 'Lat 3', 'long 3']]
day4=Gonzalo[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 4', 'Lat 4', 'long 4']]
day5=Gonzalo[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 5', 'Lat 5', 'long 5']]

#transform string to datetime format
day1['Day 1'] = pd.to_datetime(day1['First date'])
day2['Day 2'] = pd.to_datetime(day2['date 2'])
day3['Day 3'] = pd.to_datetime(day3['date 3'])
day4['Day 4'] = pd.to_datetime(day4['date 4'])
day5['Day 5'] = pd.to_datetime(day5['date 5'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-1630276480961502&gt;:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day1[&#39;Day 1&#39;] = pd.to_datetime(day1[&#39;First date&#39;])
# &lt;command-1630276480961502&gt;:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#drop unnecessary columns
day1=day1.drop(['First date'], axis=1)
day2=day2.drop(['date 2'], axis=1)
day3=day3.drop(['date 3'], axis=1)
day4=day4.drop(['date 4'], axis=1)
day5=day5.drop(['date 5'], axis=1)

#rename columns
day1 = day1.rename(columns={'Day 1': 'date', 'Lat 1': 'lat', 'long 1': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day2 = day2.rename(columns={'Day 2': 'date', 'Lat 2': 'lat', 'long 2': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day3 = day3.rename(columns={'Day 3': 'date', 'Lat 3': 'lat', 'long 3': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day4 = day4.rename(columns={'Day 4': 'date', 'Lat 4': 'lat', 'long 4': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day5 = day5.rename(columns={'Day 5': 'date', 'Lat 5': 'lat', 'long 5': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# append days dataframes into one 
GonzaloTrack=day1.append([day2, day3, day4, day5]) 
GonzaloTrack
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[375]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Category</th>
#       <th>Mx winds</th>
#       <th>Dates</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6</th>
#       <td>Gonzalo</td>
# ...

# %%
f13=folium.FeatureGroup(name='Gonzalo'.format(txt='cyan',col='cyan'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Adding Gonzalo's 5-day track

for index, row in GonzaloTrack.iterrows():
        popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
        folium.CircleMarker([row['lat'], row['lon']],
                            radius=6, color='black',fill_color='cyan',
                            popup=popup).add_to(f13)         
#adding trajectory 

pointsg = []
for idx, point in GonzaloTrack.iterrows():    
        pointsg.append((point['lat'], point['lon']))
popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
folium.PolyLine(pointsg, 
                color='cyan', popup=popup).add_to(f13)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[377]: &lt;folium.vector_layers.PolyLine at 0x7f0737f61a90&gt;</div>

# %%
# f13.add_to(Atlantic2020)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Ten
Ten= storms[(storms['Given Name'] == 'Ten')]

# Dropping columns with NaN values 
Ten= Ten.dropna(axis=1) 

# drop columns
# Ten = t.drop(['Given Name','Dates', 'Category','Mx sustained winds(Mx gusts)'], axis=1)
Ten
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[379]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Given Name</th>
#       <th>Dates</th>
#       <th>Category</th>
#       <th>Mx sustained winds(Mx gusts)</th>
#       <th>Lat 1</th>
#       <th>long 1</th>
#       <th>First date</th>
#       <th>Lat 2</th>
#       <th>long 2</th>
# ...

# %%
#breaking Ten into small dataframes (per day)
day1=Ten[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','First date','Lat 1', 'long 1']]
day2=Ten[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 2', 'Lat 2', 'long 2']]
day3=Ten[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 3', 'Lat 3', 'long 3']]

#transform string to datetime formay
day1['Day 1'] = pd.to_datetime(day1['First date'])
day2['Day 2'] = pd.to_datetime(day2['date 2'])
day3['Day 3'] = pd.to_datetime(day3['date 3'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-1630276480961509&gt;:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day1[&#39;Day 1&#39;] = pd.to_datetime(day1[&#39;First date&#39;])
# &lt;command-1630276480961509&gt;:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#drop unnecessary columns
day1=day1.drop(['First date'], axis=1)
day2=day2.drop(['date 2'], axis=1)
day3=day3.drop(['date 3'], axis=1)

#rename columns
day1 = day1.rename(columns={'Day 1': 'date', 'Lat 1': 'lat', 'long 1': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day2 = day2.rename(columns={'Day 2': 'date', 'Lat 2': 'lat', 'long 2': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day3 = day3.rename(columns={'Day 3': 'date', 'Lat 3': 'lat', 'long 3': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# append days dataframes into one 
TenTrack=day1.append([day2, day3]) 
TenTrack
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[382]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Category</th>
#       <th>Mx winds</th>
#       <th>Dates</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>9</th>
#       <td>Ten</td>
# ...

# %%
f14=folium.FeatureGroup(name='ten'.format(txt='pink',col='pink'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Adding Ten 3-day track

for index, row in TenTrack.iterrows():
       popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
       folium.CircleMarker([row['lat'], row['lon']],
                            radius=6, color='black',fill_color='pink',
                            popup=popup).add_to(f14)         
#adding trajectory 

pointsTen = []
for idx, point in TenTrack.iterrows():    
        pointsTen.append((point['lat'], point['lon']))
popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
folium.PolyLine(pointsTen, color='pink', popup=popup).add_to(f14)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[384]: &lt;folium.vector_layers.PolyLine at 0x7f0737f52730&gt;</div>

# %%
# f14.add_to(Atlantic2020)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Josephine
Josephine = storms[(storms['Given Name'] == 'Josephine')]

# Dropping columns with NaN values 
Josephine = Josephine.dropna(axis=1) 

# drop columns
# Josephine = J.drop(['Given Name','Dates', 'Category','Mx sustained winds(Mx gusts)'], axis=1)
Josephine
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[386]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Given Name</th>
#       <th>Dates</th>
#       <th>Category</th>
#       <th>Mx sustained winds(Mx gusts)</th>
#       <th>Lat 1</th>
#       <th>long 1</th>
#       <th>First date</th>
#       <th>Lat 2</th>
#       <th>long 2</th>
# ...

# %%
#breaking into small dataframes (per day)
day1=Josephine[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','First date','Lat 1', 'long 1']]
day2=Josephine[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 2', 'Lat 2', 'long 2']]
day3=Josephine[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 3', 'Lat 3', 'long 3']]
day4=Josephine[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 4', 'Lat 4', 'long 4']]
day5=Josephine[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 5', 'Lat 5', 'long 5']]
day6=Josephine[['Given Name','Category','Mx sustained winds(Mx gusts)','Dates','date 6', 'Lat 6', 'long 6']]

#transform string to datetime format
day1['Day 1'] = pd.to_datetime(day1['First date'])
day2['Day 2'] = pd.to_datetime(day2['date 2'])
day3['Day 3'] = pd.to_datetime(day3['date 3'])
day4['Day 4'] = pd.to_datetime(day4['date 4'])
day5['Day 5'] = pd.to_datetime(day5['date 5'])
day6['Day 6'] = pd.to_datetime(day6['date 6'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;command-1630276480961516&gt;:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day1[&#39;Day 1&#39;] = pd.to_datetime(day1[&#39;First date&#39;])
# &lt;command-1630276480961516&gt;:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#drop columns
day1=day1.drop(['First date'], axis=1)
day2=day2.drop(['date 2'], axis=1)
day3=day3.drop(['date 3'], axis=1)
day4=day4.drop(['date 4'], axis=1)
day5=day5.drop(['date 5'], axis=1)
day6=day6.drop(['date 6'], axis=1)

#rename columns
day1 = day1.rename(columns={'Day 1': 'date', 'Lat 1': 'lat', 'long 1': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day2 = day2.rename(columns={'Day 2': 'date', 'Lat 2': 'lat', 'long 2': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day3 = day3.rename(columns={'Day 3': 'date', 'Lat 3': 'lat', 'long 3': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day4 = day4.rename(columns={'Day 4': 'date', 'Lat 4': 'lat', 'long 4': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day5 = day5.rename(columns={'Day 5': 'date', 'Lat 5': 'lat', 'long 5': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
day6 = day6.rename(columns={'Day 6': 'date', 'Lat 6': 'lat', 'long 6': 'lon','Mx sustained winds(Mx gusts)':'Mx winds','Given Name':'Name'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# append days dataframes into one 
JosephineTrack=day1.append([day2, day3, day4, day5, day6]) 
JosephineTrack
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[389]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Category</th>
#       <th>Mx winds</th>
#       <th>Dates</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10</th>
#       <td>Josephine</td>
# ...

# %%
f15=folium.FeatureGroup(name='Josephine'.format(txt='tan',col='tan'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Adding Josephine 6-day track

for index, row in JosephineTrack.iterrows():
       popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
       folium.CircleMarker([row['lat'], row['lon']],
                            radius=6, color='black',fill_color='tan',
                            popup=popup).add_to(f15)         
#adding trajectory 

pointsj = []
for idx, point in JosephineTrack.iterrows():    
        pointsj.append((point['lat'], point['lon']))
popup=folium.Popup('Name : '+str(row['Name'])+'\n'+'Date :'+str(row['date'])+'\n'+'Status :'+str(row['Category'])+'\n'+'Max wind :'+str(row['Mx winds']),max_width=800)
folium.PolyLine(pointsj, color='tan',  popup=popup).add_to(f15)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[391]: &lt;folium.vector_layers.PolyLine at 0x7f0737f814f0&gt;</div>

# %%
# f15.add_to(Atlantic2020)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# f1.add_to(Atlantic2021)
# f2.add_to(Atlantic2021)
# f3.add_to(Atlantic2021)
# f4.add_to(Atlantic2021)
# f5.add_to(Atlantic2021)
# f6.add_to(Atlantic2021)
# f7.add_to(Atlantic2021)
# f8.add_to(Atlantic2021)
# f9.add_to(Atlantic2021)
# f10.add_to(Atlantic2021)
# f11.add_to(Atlantic2021)
# f12.add_to(Atlantic2021)
# f13.add_to(Atlantic2021)
# f14.add_to(Atlantic2021)
# f15.add_to(Atlantic2021)

# folium.LayerControl().add_to(Atlantic2021)
# Atlantic2021
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Atlanticbasin = folium.Map(
    location=[18.46633000, -66.10572000],   
    zoom_start=4,tiles='Stamen Terrain')
Atlanticbasin
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[394]: </div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
# ...

# %%
f1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[396]: &lt;folium.map.FeatureGroup at 0x7f073800f460&gt;</div>

# %%
f15
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[397]: &lt;folium.map.FeatureGroup at 0x7f0737f42700&gt;</div>
